# %%
import numpy as np
import pywt
import pywt.data
import matplotlib.pyplot as plt
import cv2

# %%
def wave_trans(images):
    # convert to numpy
#     images = images.numpy() # making images an nchw numpy array
#     images = images[:,:] # making images an hw numpy array
    coeffs2 = pywt.dwt2(images, 'bior4.4')
    LL, (LH, HL, HH) = coeffs2

    # LL is an hw numpy array

    # convert LL into a torch tensor of NCHW

    height = LL.shape[0]
    width = LL.shape[1]
#     LL = torch.from_numpy(LL)
#     LL = torch.reshape(LL,(1, 1, height, width))
    
    return(LL)

# %%
img = cv2.imread('test_edge.png', 0)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (384, 544)

# %%
LL = wave_trans(img)

# %%
LL.shape
# Out:
# (196, 276)

# %%
plt.imshow(LL, cmap = 'gray')
