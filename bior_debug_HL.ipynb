# %%
import os
import sys
import torch
import argparse
import torchvision
import numpy as np
import torch.nn as nn
import scipy.io as sio
from PIL import Image
from tqdm import tqdm
from datetime import datetime
from collections import defaultdict
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from os.path import join, isdir, abspath, dirname
import pywt
import pywt.data
# Customized import.
from networks import HED
from datasets import BsdsDataset
from utils import Logger, AverageMeter, \
    load_checkpoint, save_checkpoint, load_vgg16_caffe, load_pretrained_caffe


# # Parse arguments.
# parser = argparse.ArgumentParser(description='HED training.')
# # 1. Actions.
# parser.add_argument('--test',             default=False,             help='Only test the model.', action='store_true')
# # 2. Counts.
# parser.add_argument('--train_batch_size', default=1,    type=int,   metavar='N', help='Training batch size.')
# parser.add_argument('--test_batch_size',  default=1,    type=int,   metavar='N', help='Test batch size.')
# parser.add_argument('--train_iter_size',  default=10,   type=int,   metavar='N', help='Training iteration size.')
# parser.add_argument('--max_epoch',        default=40,   type=int,   metavar='N', help='Total epochs.')
# parser.add_argument('--print_freq',       default=500,  type=int,   metavar='N', help='Print frequency.')
# # 3. Optimizer settings.
# parser.add_argument('--lr',               default=1e-6, type=float, metavar='F', help='Initial learning rate.')
# parser.add_argument('--lr_stepsize',      default=1e4,  type=int,   metavar='N', help='Learning rate step size.')
# # Note: Step size is based on number of iterations, not number of batches.
# #   https://github.com/s9xie/hed/blob/94fb22f10cbfec8d84fbc0642b224022014b6bd6/src/caffe/solver.cpp#L498
# parser.add_argument('--lr_gamma',         default=0.1,  type=float, metavar='F', help='Learning rate decay (gamma).')
# parser.add_argument('--momentum',         default=0.9,  type=float, metavar='F', help='Momentum.')
# parser.add_argument('--weight_decay',     default=2e-4, type=float, metavar='F', help='Weight decay.')
# # 4. Files and folders.
# parser.add_argument('--vgg16_caffe',      default='',                help='Resume VGG-16 Caffe parameters.')
# parser.add_argument('--checkpoint',       default='',                help='Resume the checkpoint.')
# parser.add_argument('--caffe_model',      default='',                help='Resume HED Caffe model.')
# parser.add_argument('--output',           default='./output_LL_bior',        help='Output folder.')
# parser.add_argument('--dataset',          default='./data/HED-BSDS/LL_bior', help='HED-BSDS dataset folder.')
# # 5. Others.
# parser.add_argument('--cpu',              default=False,             help='Enable CPU mode.', action='store_true')
# args = parser.parse_args()

# Set device.
device = torch.device('cuda')

print(device)

def train(train_loader, net, opt, lr_schd, epoch, save_dir):
    """ Training procedure. """
    # Create the directory.
    if not isdir(save_dir):
        os.makedirs(save_dir)
    # Switch to train mode and clear the gradient.
    net.train()
    opt.zero_grad()
    # Initialize meter and list.
    batch_loss_meter = AverageMeter()
    # Note: The counter is used here to record number of batches in current training iteration has been processed.
    #       It aims to have large training iteration number even if GPU memory is not enough. However, such trick
    #       can be used because batch normalization is not used in the network architecture.
    counter = 0
    for batch_index, (images, edges) in enumerate(tqdm(train_loader)):
        # Adjust learning rate and modify counter following Caffe's way.
        if counter == 0:
            lr_schd.step()  # Step at the beginning of the iteration.
        counter += 1
        
        # take DWT of image here and set edges to LL
        # edges is in pytorch format
        
        edges = wave_trans(edges)
        
        
        # Get images and edges from current batch.
        images, edges = images.to(device), edges.to(device)
        # Generate predictions.
        preds_list = net(images)
        # Calculate the loss of current batch (sum of all scales and fused).
        # Note: Here we mimic the "iteration" in official repository: iter_size batches will be considered together
        #       to perform one gradient update. To achieve the goal, we calculate the equivalent iteration loss
        #       eqv_iter_loss of current batch and generate the gradient. Then, instead of updating the weights,
        #       we continue to calculate eqv_iter_loss and add the newly generated gradient to current gradient.
        #       After iter_size batches, we will update the weights using the accumulated gradients and then zero
        #       the gradients.
        # Reference:
        #   https://github.com/s9xie/hed/blob/94fb22f10cbfec8d84fbc0642b224022014b6bd6/src/caffe/solver.cpp#L230
        #   https://www.zhihu.com/question/37270367
        
        
        batch_loss = sum([weighted_cross_entropy_loss(preds, edges) for preds in preds_list])
        eqv_iter_loss = batch_loss / train_iter_size

        # Generate the gradient and accumulate (using equivalent average loss).
        eqv_iter_loss.backward()
        if counter == train_iter_size:
            opt.step()
            opt.zero_grad()
            counter = 0  # Reset the counter.
        # Record loss.
        batch_loss_meter.update(batch_loss.item())
        # Log and save intermediate images.
        if batch_index % print_freq == print_freq - 1:
            # Log.
            print(('Training epoch:{}/{}, batch:{}/{} current iteration:{}, ' +
                   'current batch batch_loss:{}, epoch average batch_loss:{}, learning rate list:{}.').format(
                   epoch, max_epoch, batch_index, len(train_loader), lr_schd.last_epoch,
                   batch_loss_meter.val, batch_loss_meter.avg, lr_schd.get_lr()))
            # Generate intermediate images.
            preds_list_and_edges = preds_list + [edges]
            _, _, h, w = preds_list_and_edges[0].shape
            interm_images = torch.zeros((len(preds_list_and_edges), 1, h, w))
            for i in range(len(preds_list_and_edges)):
                # Only fetch the first image in the batch.
                interm_images[i, 0, :, :] = preds_list_and_edges[i][0, 0, :, :]
            # Save the images.
            torchvision.utils.save_image(interm_images, join(save_dir, 'batch-{}-1st-image.png'.format(batch_index)))
    # Return the epoch average batch_loss.
    return batch_loss_meter.avg


def test(test_loader, net, save_dir):
    """ Test procedure. """
    # Create the directories.
    if not isdir(save_dir):
        os.makedirs(save_dir)
    save_png_dir = join(save_dir, 'png')
    if not isdir(save_png_dir):
        os.makedirs(save_png_dir)
    save_mat_dir = join(save_dir, 'mat')
    if not isdir(save_mat_dir):
        os.makedirs(save_mat_dir)
    # Switch to evaluation mode.
    net.eval()
    # Generate predictions and save.
    assert test_batch_size == 1  # Currently only support test batch size 1.
    for batch_index, images in enumerate(tqdm(test_loader)):
        images = images.cuda()
        _, _, h, w = images.shape
        preds_list = net(images)
        fuse       = preds_list[-1].detach().cpu().numpy()[0, 0]  # Shape: [h, w].
        name       = test_loader.dataset.images_name[batch_index]
        sio.savemat(join(save_mat_dir, '{}.mat'.format(name)), {'result': fuse})
        Image.fromarray((fuse * 255).astype(np.uint8)).save(join(save_png_dir, '{}.png'.format(name)))
        # print('Test batch {}/{}.'.format(batch_index + 1, len(test_loader)))


def weighted_cross_entropy_loss(preds, edges):
    """ Calculate sum of weighted cross entropy loss. """
    # Reference:
    #   hed/src/caffe/layers/sigmoid_cross_entropy_loss_layer.cpp
    #   https://github.com/s9xie/hed/issues/7
    
        
    
    
    mask = (edges > 0.5).float()
    b, c, h, w = mask.shape
    num_pos = torch.sum(mask, dim=[1, 2, 3]).float()  # Shape: [b,].
    num_neg = c * h * w - num_pos                     # Shape: [b,].
    weight = torch.zeros_like(mask)
    weight[edges > 0.5]  = num_neg / (num_pos + num_neg)
    weight[edges <= 0.5] = num_pos / (num_pos + num_neg)
    # Calculate loss.
    losses = torch.nn.functional.binary_cross_entropy(preds.float(), edges.float(), weight=weight, reduction='none')
    loss   = torch.sum(losses) / b
    return loss
# Out:
# cuda

# %%
op_dir = 'output_HL_bior'
data_dir = './data/HED-BSDS/HL_bior'
lr = 1e-6
weight_decay = 2e-4
momentum = 0.9
lr_stepsize = 1e4
lr_gamma = 0.1
max_epoch = 5
test_batch_size = 1
train_iter_size = 10
print_freq = 500

# %%
def wave_trans(images):
    # convert to numpy
    images = images.numpy() # making images an nchw numpy array
    images = images[0,0,:,:] # making images an hw numpy array
    coeffs2 = pywt.dwt2(images, 'bior4.4')
    LL, (LH, HL, HH) = coeffs2

    # HL is an hw numpy array

    # convert HL into a torch tensor of NCHW

    height = HL.shape[0]
    width = HL.shape[1]
    HL = torch.from_numpy(HL)
    HL = torch.reshape(HL,(1, 1, height, width))
    
    return(HL)

# %%
################################################
# I. Miscellaneous.
################################################
# Create the output directory.
# current_dir = abspath(dirname(__file__))
current_dir = os.getcwd()
output_dir = join(current_dir, op_dir)

# %%
if not isdir(output_dir):
    os.makedirs(output_dir)

# %%
# Set logger.
now_str = datetime.now().strftime('%y%m%d-%H%M%S')
log = Logger(join(output_dir, 'log-{}.txt'.format(now_str)))
sys.stdout = log  # Overwrite the standard output.
# Out:
# module.conv1_1.weight      lr:    1 decay:1
# module.conv1_1.bias        lr:    2 decay:0
# module.conv1_2.weight      lr:    1 decay:1
# module.conv1_2.bias        lr:    2 decay:0
# module.conv2_1.weight      lr:    1 decay:1
# module.conv2_1.bias        lr:    2 decay:0
# module.conv2_2.weight      lr:    1 decay:1
# module.conv2_2.bias        lr:    2 decay:0
# module.conv3_1.weight      lr:    1 decay:1
# module.conv3_1.bias        lr:    2 decay:0
# module.conv3_2.weight      lr:    1 decay:1
# module.conv3_2.bias        lr:    2 decay:0
# module.conv3_3.weight      lr:    1 decay:1
# module.conv3_3.bias        lr:    2 decay:0
# module.conv4_1.weight      lr:    1 decay:1
# module.conv4_1.bias        lr:    2 decay:0
# module.conv4_2.weight      lr:    1 decay:1
# module.conv4_2.bias        lr:    2 decay:0
# module.conv4_3.weight      lr:    1 decay:1
# module.conv4_3.bias        lr:    2 decay:0
# module.conv5_1.weight      lr:  100 decay:1
# module.conv5_1.bias        lr:  200 decay:0
# module.conv5_2.weight      lr:  100 decay:1
# module.conv5_2.bias        lr:  200 decay:0
# module.conv5_3.weight      lr:  100 decay:1
# module.conv5_3.bias        lr:  200 decay:0
# module.score_dsn1.weight   lr: 0.01 decay:1
# module.score_dsn1.bias     lr: 0.02 decay:0
# module.score_dsn2.weight   lr: 0.01 decay:1
# module.score_dsn2.bias     lr: 0.02 decay:0
# module.score_dsn3.weight   lr: 0.01 decay:1
# module.score_dsn3.bias     lr: 0.02 decay:0
# module.score_dsn4.weight   lr: 0.01 decay:1
# module.score_dsn4.bias     lr: 0.02 decay:0
# module.score_dsn5.weight   lr: 0.01 decay:1
# module.score_dsn5.bias     lr: 0.02 decay:0
# module.score_final.weight  lr:0.001 decay:1
# module.score_final.bias    lr:0.002 decay:0
# => Start loading parameters...
# => Loaded module.conv1_1.weight.
# => Loaded module.conv1_1.bias.
# => Loaded module.conv1_2.weight.
# => Loaded module.conv1_2.bias.
# => Loaded module.conv2_1.weight.
# => Loaded module.conv2_1.bias.
# => Loaded module.conv2_2.weight.
# => Loaded module.conv2_2.bias.
# => Loaded module.conv3_1.weight.
# => Loaded module.conv3_1.bias.
# => Loaded module.conv3_2.weight.
# => Loaded module.conv3_2.bias.
# => Loaded module.conv3_3.weight.
# => Loaded module.conv3_3.bias.
# => Loaded module.conv4_1.weight.
# => Loaded module.conv4_1.bias.
# => Loaded module.conv4_2.weight.
# => Loaded module.conv4_2.bias.
# => Loaded module.conv4_3.weight.
# => Loaded module.conv4_3.bias.
# => Loaded module.conv5_1.weight.
# => Loaded module.conv5_1.bias.
# => Loaded module.conv5_2.weight.
# => Loaded module.conv5_2.bias.
# => Loaded module.conv5_3.weight.
# => Loaded module.conv5_3.bias.
# => Finish loading parameters.
# Initial test...
# Training epoch:0/5, batch:499/28800 current iteration:50, current batch batch_loss:264.460693359375, epoch average batch_loss:842.3604029865265, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:999/28800 current iteration:100, current batch batch_loss:3191.654296875, epoch average batch_loss:794.0556982717515, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:1499/28800 current iteration:150, current batch batch_loss:450.1269226074219, epoch average batch_loss:769.9574790108999, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:1999/28800 current iteration:200, current batch batch_loss:109.84744262695312, epoch average batch_loss:755.1724227213859, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:2499/28800 current iteration:250, current batch batch_loss:448.57342529296875, epoch average batch_loss:753.4140076992035, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:2999/28800 current iteration:300, current batch batch_loss:411.15008544921875, epoch average batch_loss:757.8816415778796, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:3499/28800 current iteration:350, current batch batch_loss:245.4098663330078, epoch average batch_loss:752.4308070366723, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:3999/28800 current iteration:400, current batch batch_loss:1220.3719482421875, epoch average batch_loss:750.6071843316555, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:4499/28800 current iteration:450, current batch batch_loss:207.7353973388672, epoch average batch_loss:748.4330161283281, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:4999/28800 current iteration:500, current batch batch_loss:119.87535095214844, epoch average batch_loss:747.6517928533555, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:5499/28800 current iteration:550, current batch batch_loss:700.9592895507812, epoch average batch_loss:745.1183445124193, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:5999/28800 current iteration:600, current batch batch_loss:443.6915588378906, epoch average batch_loss:741.4410556497573, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:6499/28800 current iteration:650, current batch batch_loss:392.06854248046875, epoch average batch_loss:743.6350348727887, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:6999/28800 current iteration:700, current batch batch_loss:197.19717407226562, epoch average batch_loss:737.808097329821, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:7499/28800 current iteration:750, current batch batch_loss:486.5398254394531, epoch average batch_loss:732.1327417330424, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:7999/28800 current iteration:800, current batch batch_loss:320.2102355957031, epoch average batch_loss:732.6103023583889, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:8499/28800 current iteration:850, current batch batch_loss:871.2714233398438, epoch average batch_loss:733.1482750605414, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:8999/28800 current iteration:900, current batch batch_loss:1475.30615234375, epoch average batch_loss:735.4943104932573, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:9499/28800 current iteration:950, current batch batch_loss:266.8287048339844, epoch average batch_loss:732.9881031600551, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:9999/28800 current iteration:1000, current batch batch_loss:1719.9925537109375, epoch average batch_loss:730.9178566587448, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:10499/28800 current iteration:1050, current batch batch_loss:826.5227661132812, epoch average batch_loss:730.9800074610029, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:10999/28800 current iteration:1100, current batch batch_loss:707.6154174804688, epoch average batch_loss:731.4452027601762, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:11499/28800 current iteration:1150, current batch batch_loss:341.8153381347656, epoch average batch_loss:732.8182821051556, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:11999/28800 current iteration:1200, current batch batch_loss:483.32525634765625, epoch average batch_loss:732.2414846466382, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:12499/28800 current iteration:1250, current batch batch_loss:195.39329528808594, epoch average batch_loss:731.0582591270447, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:12999/28800 current iteration:1300, current batch batch_loss:913.68603515625, epoch average batch_loss:733.0943446727166, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:13499/28800 current iteration:1350, current batch batch_loss:51.003807067871094, epoch average batch_loss:731.5428208423191, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:13999/28800 current iteration:1400, current batch batch_loss:689.8938598632812, epoch average batch_loss:732.3140378550121, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:14499/28800 current iteration:1450, current batch batch_loss:746.1193237304688, epoch average batch_loss:733.3297611940976, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:14999/28800 current iteration:1500, current batch batch_loss:261.4451904296875, epoch average batch_loss:733.1389668186823, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:15499/28800 current iteration:1550, current batch batch_loss:447.8966369628906, epoch average batch_loss:732.0771403614782, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:15999/28800 current iteration:1600, current batch batch_loss:342.5384521484375, epoch average batch_loss:733.2078528004289, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:16499/28800 current iteration:1650, current batch batch_loss:879.9058227539062, epoch average batch_loss:733.101734967145, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:16999/28800 current iteration:1700, current batch batch_loss:618.3052368164062, epoch average batch_loss:732.0757528662401, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:17499/28800 current iteration:1750, current batch batch_loss:241.99685668945312, epoch average batch_loss:731.2108075866154, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:17999/28800 current iteration:1800, current batch batch_loss:2353.47314453125, epoch average batch_loss:732.2010939815839, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:18499/28800 current iteration:1850, current batch batch_loss:376.19696044921875, epoch average batch_loss:731.7045960198996, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:18999/28800 current iteration:1900, current batch batch_loss:653.0333251953125, epoch average batch_loss:731.804335258534, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:19499/28800 current iteration:1950, current batch batch_loss:461.2308654785156, epoch average batch_loss:731.1329874645625, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:19999/28800 current iteration:2000, current batch batch_loss:166.06202697753906, epoch average batch_loss:731.58528774724, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:20499/28800 current iteration:2050, current batch batch_loss:440.24737548828125, epoch average batch_loss:732.1567010973023, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:20999/28800 current iteration:2100, current batch batch_loss:760.0479125976562, epoch average batch_loss:730.4845755513963, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:21499/28800 current iteration:2150, current batch batch_loss:303.0028076171875, epoch average batch_loss:730.3774692176996, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:21999/28800 current iteration:2200, current batch batch_loss:3599.14306640625, epoch average batch_loss:729.9104771721579, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:22499/28800 current iteration:2250, current batch batch_loss:1404.443359375, epoch average batch_loss:730.23543003557, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:22999/28800 current iteration:2300, current batch batch_loss:495.07647705078125, epoch average batch_loss:728.8160646682823, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:23499/28800 current iteration:2350, current batch batch_loss:750.589111328125, epoch average batch_loss:728.6618212644292, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:23999/28800 current iteration:2400, current batch batch_loss:681.6978759765625, epoch average batch_loss:728.8636846349636, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:24499/28800 current iteration:2450, current batch batch_loss:280.9730529785156, epoch average batch_loss:728.3938244926686, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:24999/28800 current iteration:2500, current batch batch_loss:627.2725830078125, epoch average batch_loss:728.7070155345535, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:25499/28800 current iteration:2550, current batch batch_loss:1750.1536865234375, epoch average batch_loss:728.0304207304039, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:25999/28800 current iteration:2600, current batch batch_loss:600.6742553710938, epoch average batch_loss:727.7413384162096, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:26499/28800 current iteration:2650, current batch batch_loss:1041.8358154296875, epoch average batch_loss:727.0018141274003, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:26999/28800 current iteration:2700, current batch batch_loss:2519.22607421875, epoch average batch_loss:726.272588459898, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:27499/28800 current iteration:2750, current batch batch_loss:1075.27783203125, epoch average batch_loss:726.4974011190587, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:27999/28800 current iteration:2800, current batch batch_loss:221.08840942382812, epoch average batch_loss:725.5070027002947, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:0/5, batch:28499/28800 current iteration:2850, current batch batch_loss:850.3063354492188, epoch average batch_loss:725.1617239970492, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:499/28800 current iteration:2930, current batch batch_loss:540.3773193359375, epoch average batch_loss:712.4377695198059, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:999/28800 current iteration:2980, current batch batch_loss:179.17837524414062, epoch average batch_loss:698.6665552387237, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:1499/28800 current iteration:3030, current batch batch_loss:432.5556945800781, epoch average batch_loss:710.2891567357382, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:1999/28800 current iteration:3080, current batch batch_loss:463.51629638671875, epoch average batch_loss:692.6837238922119, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:2499/28800 current iteration:3130, current batch batch_loss:258.3089599609375, epoch average batch_loss:702.4665338745117, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:2999/28800 current iteration:3180, current batch batch_loss:459.5469665527344, epoch average batch_loss:704.6339414513906, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:3499/28800 current iteration:3230, current batch batch_loss:1496.11083984375, epoch average batch_loss:709.7342736396789, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:3999/28800 current iteration:3280, current batch batch_loss:314.4428405761719, epoch average batch_loss:716.159828350544, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:4499/28800 current iteration:3330, current batch batch_loss:2823.9111328125, epoch average batch_loss:723.232531194475, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:4999/28800 current iteration:3380, current batch batch_loss:1996.4080810546875, epoch average batch_loss:723.5042089366913, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:5499/28800 current iteration:3430, current batch batch_loss:149.4568328857422, epoch average batch_loss:717.308247670087, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:5999/28800 current iteration:3480, current batch batch_loss:469.5521240234375, epoch average batch_loss:716.9048844482104, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:6499/28800 current iteration:3530, current batch batch_loss:1509.0489501953125, epoch average batch_loss:713.2306323490143, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:6999/28800 current iteration:3580, current batch batch_loss:838.2628784179688, epoch average batch_loss:712.9719792552676, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:7499/28800 current iteration:3630, current batch batch_loss:324.7078857421875, epoch average batch_loss:713.574080911382, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:7999/28800 current iteration:3680, current batch batch_loss:224.61947631835938, epoch average batch_loss:714.2493795837164, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:8499/28800 current iteration:3730, current batch batch_loss:949.9278564453125, epoch average batch_loss:715.5896183165382, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:8999/28800 current iteration:3780, current batch batch_loss:656.0264892578125, epoch average batch_loss:715.0296485634909, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:9499/28800 current iteration:3830, current batch batch_loss:41.0410270690918, epoch average batch_loss:713.748973108392, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:9999/28800 current iteration:3880, current batch batch_loss:191.6566619873047, epoch average batch_loss:711.0994973903656, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:10499/28800 current iteration:3930, current batch batch_loss:1130.29638671875, epoch average batch_loss:709.9333199442909, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:10999/28800 current iteration:3980, current batch batch_loss:447.3805847167969, epoch average batch_loss:712.9694323460405, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:11499/28800 current iteration:4030, current batch batch_loss:185.52731323242188, epoch average batch_loss:711.5275501626471, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:11999/28800 current iteration:4080, current batch batch_loss:162.96774291992188, epoch average batch_loss:712.6606303517422, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:12499/28800 current iteration:4130, current batch batch_loss:205.3279571533203, epoch average batch_loss:712.6167311626816, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:12999/28800 current iteration:4180, current batch batch_loss:853.1795654296875, epoch average batch_loss:711.4094052675321, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:13499/28800 current iteration:4230, current batch batch_loss:833.2586669921875, epoch average batch_loss:713.3546029254419, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:13999/28800 current iteration:4280, current batch batch_loss:919.3502807617188, epoch average batch_loss:712.7398893034458, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:14499/28800 current iteration:4330, current batch batch_loss:929.54443359375, epoch average batch_loss:712.1298685712815, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:14999/28800 current iteration:4380, current batch batch_loss:203.7504119873047, epoch average batch_loss:710.3199517080625, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:15499/28800 current iteration:4430, current batch batch_loss:290.50665283203125, epoch average batch_loss:712.1222537952854, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:15999/28800 current iteration:4480, current batch batch_loss:878.2696533203125, epoch average batch_loss:713.2400183005631, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:16499/28800 current iteration:4530, current batch batch_loss:386.229248046875, epoch average batch_loss:714.249450447805, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:16999/28800 current iteration:4580, current batch batch_loss:558.2584228515625, epoch average batch_loss:714.5648536594896, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:17499/28800 current iteration:4630, current batch batch_loss:114.94033813476562, epoch average batch_loss:714.6866770147324, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:17999/28800 current iteration:4680, current batch batch_loss:343.1754150390625, epoch average batch_loss:713.4737727456887, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:18499/28800 current iteration:4730, current batch batch_loss:383.47857666015625, epoch average batch_loss:713.4107144937515, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:18999/28800 current iteration:4780, current batch batch_loss:320.89764404296875, epoch average batch_loss:714.1983674201213, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:19499/28800 current iteration:4830, current batch batch_loss:278.822509765625, epoch average batch_loss:713.5950388842118, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:19999/28800 current iteration:4880, current batch batch_loss:242.5074920654297, epoch average batch_loss:713.5753167000532, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:20499/28800 current iteration:4930, current batch batch_loss:1402.5904541015625, epoch average batch_loss:712.931651541989, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:20999/28800 current iteration:4980, current batch batch_loss:1389.367919921875, epoch average batch_loss:712.9632002318473, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:21499/28800 current iteration:5030, current batch batch_loss:436.38189697265625, epoch average batch_loss:712.1076721410751, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:21999/28800 current iteration:5080, current batch batch_loss:1446.490966796875, epoch average batch_loss:711.9988024926619, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:22499/28800 current iteration:5130, current batch batch_loss:2133.35009765625, epoch average batch_loss:711.3527811401367, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:22999/28800 current iteration:5180, current batch batch_loss:309.11474609375, epoch average batch_loss:711.5158509562948, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:23499/28800 current iteration:5230, current batch batch_loss:658.8244018554688, epoch average batch_loss:711.0633764925205, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:23999/28800 current iteration:5280, current batch batch_loss:5085.3349609375, epoch average batch_loss:711.3262710975011, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:24499/28800 current iteration:5330, current batch batch_loss:418.7685241699219, epoch average batch_loss:711.2060440231635, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:24999/28800 current iteration:5380, current batch batch_loss:484.9623107910156, epoch average batch_loss:711.7264830999756, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:25499/28800 current iteration:5430, current batch batch_loss:483.3499755859375, epoch average batch_loss:711.3573475936441, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:25999/28800 current iteration:5480, current batch batch_loss:446.1561279296875, epoch average batch_loss:711.6996287719286, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:26499/28800 current iteration:5530, current batch batch_loss:220.4773406982422, epoch average batch_loss:712.560361899142, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:26999/28800 current iteration:5580, current batch batch_loss:809.4730834960938, epoch average batch_loss:712.5112242237198, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:27499/28800 current iteration:5630, current batch batch_loss:153.44674682617188, epoch average batch_loss:712.7939228409681, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:27999/28800 current iteration:5680, current batch batch_loss:324.91827392578125, epoch average batch_loss:712.0651726154089, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:1/5, batch:28499/28800 current iteration:5730, current batch batch_loss:1508.0423583984375, epoch average batch_loss:712.775807934761, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:499/28800 current iteration:5810, current batch batch_loss:281.655517578125, epoch average batch_loss:677.9108814659119, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:999/28800 current iteration:5860, current batch batch_loss:452.41680908203125, epoch average batch_loss:674.8077787494659, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:1499/28800 current iteration:5910, current batch batch_loss:614.1077880859375, epoch average batch_loss:660.5327091534932, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:1999/28800 current iteration:5960, current batch batch_loss:84.76687622070312, epoch average batch_loss:679.7930533895493, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:2499/28800 current iteration:6010, current batch batch_loss:301.7120666503906, epoch average batch_loss:678.0299530769348, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:2999/28800 current iteration:6060, current batch batch_loss:366.2900695800781, epoch average batch_loss:685.1572202835083, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:3499/28800 current iteration:6110, current batch batch_loss:322.99652099609375, epoch average batch_loss:685.3152029887608, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:3999/28800 current iteration:6160, current batch batch_loss:325.7796936035156, epoch average batch_loss:686.6382665977478, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:4499/28800 current iteration:6210, current batch batch_loss:283.61474609375, epoch average batch_loss:692.9611844509973, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:4999/28800 current iteration:6260, current batch batch_loss:851.5706787109375, epoch average batch_loss:691.3911735803604, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:5499/28800 current iteration:6310, current batch batch_loss:668.1995849609375, epoch average batch_loss:694.2390617843974, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:5999/28800 current iteration:6360, current batch batch_loss:295.9087219238281, epoch average batch_loss:695.9553905984561, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:6499/28800 current iteration:6410, current batch batch_loss:564.1151123046875, epoch average batch_loss:697.8932622344677, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:6999/28800 current iteration:6460, current batch batch_loss:452.74609375, epoch average batch_loss:701.173673786027, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:7499/28800 current iteration:6510, current batch batch_loss:389.35546875, epoch average batch_loss:706.0660148939769, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:7999/28800 current iteration:6560, current batch batch_loss:527.525390625, epoch average batch_loss:705.1484011677503, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:8499/28800 current iteration:6610, current batch batch_loss:297.9142761230469, epoch average batch_loss:701.2978684379353, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:8999/28800 current iteration:6660, current batch batch_loss:563.536376953125, epoch average batch_loss:702.6034082316293, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:9499/28800 current iteration:6710, current batch batch_loss:957.7023315429688, epoch average batch_loss:703.192563285125, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:9999/28800 current iteration:6760, current batch batch_loss:421.4658203125, epoch average batch_loss:700.8091091164589, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:10499/28800 current iteration:6810, current batch batch_loss:288.1650085449219, epoch average batch_loss:697.9442796033223, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:10999/28800 current iteration:6860, current batch batch_loss:1814.43896484375, epoch average batch_loss:702.2810708682321, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:11499/28800 current iteration:6910, current batch batch_loss:303.4557189941406, epoch average batch_loss:702.5945016149437, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:11999/28800 current iteration:6960, current batch batch_loss:101.0397720336914, epoch average batch_loss:704.0318929106395, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:12499/28800 current iteration:7010, current batch batch_loss:334.2871398925781, epoch average batch_loss:702.7828633990479, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:12999/28800 current iteration:7060, current batch batch_loss:1312.90966796875, epoch average batch_loss:702.6005378915347, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:13499/28800 current iteration:7110, current batch batch_loss:757.5775146484375, epoch average batch_loss:701.824379632314, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:13999/28800 current iteration:7160, current batch batch_loss:732.8350830078125, epoch average batch_loss:702.7859817350933, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:14499/28800 current iteration:7210, current batch batch_loss:416.2891845703125, epoch average batch_loss:702.6076439074812, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:14999/28800 current iteration:7260, current batch batch_loss:182.86790466308594, epoch average batch_loss:704.0994816627502, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:15499/28800 current iteration:7310, current batch batch_loss:520.1309204101562, epoch average batch_loss:702.3435002982231, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:15999/28800 current iteration:7360, current batch batch_loss:246.30291748046875, epoch average batch_loss:703.5252758739591, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:16499/28800 current iteration:7410, current batch batch_loss:600.0904541015625, epoch average batch_loss:704.1959453753269, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:16999/28800 current iteration:7460, current batch batch_loss:324.123046875, epoch average batch_loss:706.651206894538, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:17499/28800 current iteration:7510, current batch batch_loss:783.5751953125, epoch average batch_loss:705.6031531516484, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:17999/28800 current iteration:7560, current batch batch_loss:240.2221221923828, epoch average batch_loss:706.4233789614042, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:18499/28800 current iteration:7610, current batch batch_loss:417.8251037597656, epoch average batch_loss:705.7688466637586, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:18999/28800 current iteration:7660, current batch batch_loss:1088.6083984375, epoch average batch_loss:707.2327741932618, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:19499/28800 current iteration:7710, current batch batch_loss:173.120361328125, epoch average batch_loss:706.3063610729804, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:19999/28800 current iteration:7760, current batch batch_loss:583.0890502929688, epoch average batch_loss:707.4027282598972, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:20499/28800 current iteration:7810, current batch batch_loss:521.469970703125, epoch average batch_loss:707.4970623126611, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:20999/28800 current iteration:7860, current batch batch_loss:908.8524169921875, epoch average batch_loss:709.2023409802119, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:21499/28800 current iteration:7910, current batch batch_loss:884.1541748046875, epoch average batch_loss:709.513083842832, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:21999/28800 current iteration:7960, current batch batch_loss:570.1126098632812, epoch average batch_loss:709.0397403316498, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:22499/28800 current iteration:8010, current batch batch_loss:375.2153015136719, epoch average batch_loss:708.969212531111, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:22999/28800 current iteration:8060, current batch batch_loss:3430.87158203125, epoch average batch_loss:709.6337759547855, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:23499/28800 current iteration:8110, current batch batch_loss:250.44775390625, epoch average batch_loss:709.6509243078029, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:23999/28800 current iteration:8160, current batch batch_loss:316.871337890625, epoch average batch_loss:709.3509108852545, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:24499/28800 current iteration:8210, current batch batch_loss:320.9007263183594, epoch average batch_loss:709.890052854499, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:24999/28800 current iteration:8260, current batch batch_loss:912.8131713867188, epoch average batch_loss:711.0643903095246, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:25499/28800 current iteration:8310, current batch batch_loss:1317.993408203125, epoch average batch_loss:710.5551768546011, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:25999/28800 current iteration:8360, current batch batch_loss:3247.7197265625, epoch average batch_loss:710.6835505042443, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:26499/28800 current iteration:8410, current batch batch_loss:541.0631713867188, epoch average batch_loss:710.7208470395645, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:26999/28800 current iteration:8460, current batch batch_loss:1770.6944580078125, epoch average batch_loss:710.6181151168964, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:27499/28800 current iteration:8510, current batch batch_loss:183.20094299316406, epoch average batch_loss:711.0464965276544, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:27999/28800 current iteration:8560, current batch batch_loss:399.6256103515625, epoch average batch_loss:709.9381926833562, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:2/5, batch:28499/28800 current iteration:8610, current batch batch_loss:1377.5830078125, epoch average batch_loss:710.1222843247798, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:499/28800 current iteration:8690, current batch batch_loss:2373.43896484375, epoch average batch_loss:719.5117510833741, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:999/28800 current iteration:8740, current batch batch_loss:332.8448181152344, epoch average batch_loss:695.1288888130188, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:1499/28800 current iteration:8790, current batch batch_loss:1580.81103515625, epoch average batch_loss:690.281397925059, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:1999/28800 current iteration:8840, current batch batch_loss:672.1717529296875, epoch average batch_loss:709.6260785264969, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:2499/28800 current iteration:8890, current batch batch_loss:336.1245422363281, epoch average batch_loss:715.0210828353881, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:2999/28800 current iteration:8940, current batch batch_loss:2370.9560546875, epoch average batch_loss:716.1740524381001, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:3499/28800 current iteration:8990, current batch batch_loss:295.367919921875, epoch average batch_loss:710.9187868279048, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:3999/28800 current iteration:9040, current batch batch_loss:413.20489501953125, epoch average batch_loss:708.2686071169377, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:4499/28800 current iteration:9090, current batch batch_loss:146.6891326904297, epoch average batch_loss:712.9287870739831, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:4999/28800 current iteration:9140, current batch batch_loss:276.49688720703125, epoch average batch_loss:713.5368504449845, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:5499/28800 current iteration:9190, current batch batch_loss:3242.0810546875, epoch average batch_loss:715.0493356640555, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:5999/28800 current iteration:9240, current batch batch_loss:272.0337829589844, epoch average batch_loss:717.0165925863583, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:6499/28800 current iteration:9290, current batch batch_loss:857.4300537109375, epoch average batch_loss:722.8726748444484, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:6999/28800 current iteration:9340, current batch batch_loss:2122.53955078125, epoch average batch_loss:718.9282462945665, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:7499/28800 current iteration:9390, current batch batch_loss:278.4129638671875, epoch average batch_loss:720.1494892321268, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:7999/28800 current iteration:9440, current batch batch_loss:702.7677612304688, epoch average batch_loss:716.6084368495941, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:8499/28800 current iteration:9490, current batch batch_loss:169.2477569580078, epoch average batch_loss:718.0946556651171, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:8999/28800 current iteration:9540, current batch batch_loss:463.91094970703125, epoch average batch_loss:715.0849705966314, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:9499/28800 current iteration:9590, current batch batch_loss:683.4134521484375, epoch average batch_loss:712.260214885009, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:9999/28800 current iteration:9640, current batch batch_loss:211.51138305664062, epoch average batch_loss:712.2643392382622, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:10499/28800 current iteration:9690, current batch batch_loss:170.9524688720703, epoch average batch_loss:711.2768652757009, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:10999/28800 current iteration:9740, current batch batch_loss:780.9458618164062, epoch average batch_loss:710.4875834592473, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:11499/28800 current iteration:9790, current batch batch_loss:51.14213180541992, epoch average batch_loss:708.0376791954869, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:11999/28800 current iteration:9840, current batch batch_loss:290.75079345703125, epoch average batch_loss:708.505180107673, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:12499/28800 current iteration:9890, current batch batch_loss:337.5398864746094, epoch average batch_loss:709.4865291518402, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:12999/28800 current iteration:9940, current batch batch_loss:1118.0234375, epoch average batch_loss:709.9063514077847, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:13499/28800 current iteration:9990, current batch batch_loss:257.57958984375, epoch average batch_loss:709.6581178004653, learning rate list:[1e-06, 2e-06, 9.999999999999999e-05, 0.00019999999999999998, 1e-08, 2e-08, 1e-09, 2e-09].
# Training epoch:3/5, batch:13999/28800 current iteration:10040, current batch batch_loss:199.2293701171875, epoch average batch_loss:708.1367764141219, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:14499/28800 current iteration:10090, current batch batch_loss:198.01202392578125, epoch average batch_loss:707.3230600786538, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:14999/28800 current iteration:10140, current batch batch_loss:111.96807861328125, epoch average batch_loss:709.3453057424546, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:15499/28800 current iteration:10190, current batch batch_loss:96.315185546875, epoch average batch_loss:707.9044893491806, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:15999/28800 current iteration:10240, current batch batch_loss:540.8859252929688, epoch average batch_loss:706.754738768518, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:16499/28800 current iteration:10290, current batch batch_loss:388.5989685058594, epoch average batch_loss:704.7313643678029, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:16999/28800 current iteration:10340, current batch batch_loss:574.642822265625, epoch average batch_loss:705.0519489016252, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:17499/28800 current iteration:10390, current batch batch_loss:229.7373046875, epoch average batch_loss:704.9567786328452, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:17999/28800 current iteration:10440, current batch batch_loss:2451.989501953125, epoch average batch_loss:704.7941866869926, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:18499/28800 current iteration:10490, current batch batch_loss:331.23492431640625, epoch average batch_loss:704.8114939794283, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:18999/28800 current iteration:10540, current batch batch_loss:324.1830139160156, epoch average batch_loss:704.3519583848652, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:19499/28800 current iteration:10590, current batch batch_loss:456.75634765625, epoch average batch_loss:704.420928199817, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:19999/28800 current iteration:10640, current batch batch_loss:2262.388671875, epoch average batch_loss:704.5267759636403, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:20499/28800 current iteration:10690, current batch batch_loss:3603.732421875, epoch average batch_loss:706.5268759981016, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:20999/28800 current iteration:10740, current batch batch_loss:147.07810974121094, epoch average batch_loss:707.8538520105907, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:21499/28800 current iteration:10790, current batch batch_loss:490.44256591796875, epoch average batch_loss:708.1273730588957, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:21999/28800 current iteration:10840, current batch batch_loss:285.3263854980469, epoch average batch_loss:708.1195176913088, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:22499/28800 current iteration:10890, current batch batch_loss:1750.9208984375, epoch average batch_loss:708.6342538217757, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:22999/28800 current iteration:10940, current batch batch_loss:2576.134765625, epoch average batch_loss:708.2546155604073, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:23499/28800 current iteration:10990, current batch batch_loss:310.2515563964844, epoch average batch_loss:708.7278876468984, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:23999/28800 current iteration:11040, current batch batch_loss:570.208984375, epoch average batch_loss:708.0593245229323, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:24499/28800 current iteration:11090, current batch batch_loss:334.8409729003906, epoch average batch_loss:708.9704534362093, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:24999/28800 current iteration:11140, current batch batch_loss:441.03369140625, epoch average batch_loss:708.6123337977981, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:25499/28800 current iteration:11190, current batch batch_loss:241.72024536132812, epoch average batch_loss:708.2676762884178, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:25999/28800 current iteration:11240, current batch batch_loss:719.2598876953125, epoch average batch_loss:708.07162504673, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:26499/28800 current iteration:11290, current batch batch_loss:445.3539123535156, epoch average batch_loss:707.7817182908688, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:26999/28800 current iteration:11340, current batch batch_loss:414.1260986328125, epoch average batch_loss:708.1295478798902, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:27499/28800 current iteration:11390, current batch batch_loss:358.1036682128906, epoch average batch_loss:708.1650702089484, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:27999/28800 current iteration:11440, current batch batch_loss:157.76536560058594, epoch average batch_loss:707.4130900713886, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:3/5, batch:28499/28800 current iteration:11490, current batch batch_loss:1064.440673828125, epoch average batch_loss:707.0108947337468, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:4/5, batch:499/28800 current iteration:11570, current batch batch_loss:317.38720703125, epoch average batch_loss:702.2822579345703, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].
# Training epoch:4/5, batch:999/28800 current iteration:11620, current batch batch_loss:1611.491455078125, epoch average batch_loss:680.7215243301391, learning rate list:[1e-07, 2e-07, 9.999999999999999e-06, 1.9999999999999998e-05, 1e-09, 2e-09, 1.0000000000000002e-10, 2.0000000000000003e-10].

# %%
################################################
# II. Datasets.
################################################
# Datasets and dataloaders.
train_dataset = BsdsDataset(dataset_dir=data_dir, split='train')
test_dataset  = BsdsDataset(dataset_dir=data_dir, split='test')
train_loader  = DataLoader(train_dataset, batch_size=1,
                           num_workers=4, drop_last=True, shuffle=True)
test_loader   = DataLoader(test_dataset,  batch_size=1,
                           num_workers=4, drop_last=False, shuffle=False)

# %%
################################################
# III. Network and optimizer.
################################################
# Create the network in GPU.
net = nn.DataParallel(HED(device))
net.to(device)

# Initialize the weights for HED model.
def weights_init(m):
    """ Weight initialization function. """
    if isinstance(m, nn.Conv2d):
        # Initialize: m.weight.
        if m.weight.data.shape == torch.Size([1, 5, 1, 1]):
            # Constant initialization for fusion layer in HED network.
            torch.nn.init.constant_(m.weight, 0.2)
        else:
            # Zero initialization following official repository.
            # Reference: hed/docs/tutorial/layers.md
            m.weight.data.zero_()
        # Initialize: m.bias.
        if m.bias is not None:
            # Zero initialization.
            m.bias.data.zero_()
net.apply(weights_init)

# Optimizer settings.
net_parameters_id = defaultdict(list)
for name, param in net.named_parameters():
    if name in ['module.conv1_1.weight', 'module.conv1_2.weight',
                'module.conv2_1.weight', 'module.conv2_2.weight',
                'module.conv3_1.weight', 'module.conv3_2.weight', 'module.conv3_3.weight',
                'module.conv4_1.weight', 'module.conv4_2.weight', 'module.conv4_3.weight']:
        print('{:26} lr:    1 decay:1'.format(name)); net_parameters_id['conv1-4.weight'].append(param)
    elif name in ['module.conv1_1.bias', 'module.conv1_2.bias',
                  'module.conv2_1.bias', 'module.conv2_2.bias',
                  'module.conv3_1.bias', 'module.conv3_2.bias', 'module.conv3_3.bias',
                  'module.conv4_1.bias', 'module.conv4_2.bias', 'module.conv4_3.bias']:
        print('{:26} lr:    2 decay:0'.format(name)); net_parameters_id['conv1-4.bias'].append(param)
    elif name in ['module.conv5_1.weight', 'module.conv5_2.weight', 'module.conv5_3.weight']:
        print('{:26} lr:  100 decay:1'.format(name)); net_parameters_id['conv5.weight'].append(param)
    elif name in ['module.conv5_1.bias', 'module.conv5_2.bias', 'module.conv5_3.bias'] :
        print('{:26} lr:  200 decay:0'.format(name)); net_parameters_id['conv5.bias'].append(param)
    elif name in ['module.score_dsn1.weight', 'module.score_dsn2.weight',
                  'module.score_dsn3.weight', 'module.score_dsn4.weight', 'module.score_dsn5.weight']:
        print('{:26} lr: 0.01 decay:1'.format(name)); net_parameters_id['score_dsn_1-5.weight'].append(param)
    elif name in ['module.score_dsn1.bias', 'module.score_dsn2.bias',
                  'module.score_dsn3.bias', 'module.score_dsn4.bias', 'module.score_dsn5.bias']:
        print('{:26} lr: 0.02 decay:0'.format(name)); net_parameters_id['score_dsn_1-5.bias'].append(param)
    elif name in ['module.score_final.weight']:
        print('{:26} lr:0.001 decay:1'.format(name)); net_parameters_id['score_final.weight'].append(param)
    elif name in ['module.score_final.bias']:
        print('{:26} lr:0.002 decay:0'.format(name)); net_parameters_id['score_final.bias'].append(param)

# Create optimizer.
opt = torch.optim.SGD([
    {'params': net_parameters_id['conv1-4.weight']      , 'lr': lr*1    , 'weight_decay': weight_decay},
    {'params': net_parameters_id['conv1-4.bias']        , 'lr': lr*2    , 'weight_decay': 0.},
    {'params': net_parameters_id['conv5.weight']        , 'lr': lr*100  , 'weight_decay': weight_decay},
    {'params': net_parameters_id['conv5.bias']          , 'lr': lr*200  , 'weight_decay': 0.},
    {'params': net_parameters_id['score_dsn_1-5.weight'], 'lr': lr*0.01 , 'weight_decay': weight_decay},
    {'params': net_parameters_id['score_dsn_1-5.bias']  , 'lr': lr*0.02 , 'weight_decay': 0.},
    {'params': net_parameters_id['score_final.weight']  , 'lr': lr*0.001, 'weight_decay': weight_decay},
    {'params': net_parameters_id['score_final.bias']    , 'lr': lr*0.002, 'weight_decay': 0.},
], lr=lr, momentum=momentum, weight_decay=weight_decay)
# Note: In train_val.prototxt and deploy.prototxt, the learning rates of score_final.weight/bias are different.

# Learning rate scheduler.
lr_schd = lr_scheduler.StepLR(opt, step_size=lr_stepsize, gamma=lr_gamma)

# %%
################################################
# IV. Pre-trained parameters.
################################################
# Load parameters from pre-trained VGG-16 Caffe model.
# if args.vgg16_caffe:
load_vgg16_caffe(net, './data/5stage-vgg.py36pickle')

# # Resume the checkpoint.
# if args.checkpoint:
#     load_checkpoint(net, opt, args.checkpoint)  # Omit the returned values.

# # Resume the HED Caffe model.
# if args.caffe_model:
#     load_pretrained_caffe(net, args.caffe_model)

# %%
################################################
# V. Training / testing.
################################################
# if args.test is True:
#     # Only test.
#     test(test_loader, net, save_dir=join(output_dir, 'test'))
# else:
# Train.
train_epoch_losses = []
for epoch in range(max_epoch):
    # Initial test.
    if epoch == 0:
        print('Initial test...')
        test(test_loader, net, save_dir=join(output_dir, 'initial-test'))
    # Epoch training and test.
    train_epoch_loss = \
        train(train_loader, net, opt, lr_schd, epoch, save_dir=join(output_dir, 'epoch-{}-train'.format(epoch)))
    test(test_loader, net, save_dir=join(output_dir, 'epoch-{}-test'.format(epoch)))
    # Write log.
    log.flush()
    # Save checkpoint.
    save_checkpoint(state={'net': net.state_dict(), 'opt': opt.state_dict(), 'epoch': epoch},
                    path=os.path.join(output_dir, 'epoch-{}-checkpoint.pt'.format(epoch)))
    # Collect losses.
    train_epoch_losses.append(train_epoch_loss)
# Out:
# 100%|██████████| 200/200 [00:04<00:00, 47.61it/s]
#   0%|          | 0/28800 [00:00<?, ?it/s]/datasets/home/24/524/cpatil/.local/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# 100%|██████████| 28800/28800 [15:11<00:00, 31.58it/s]
# 100%|██████████| 200/200 [00:05<00:00, 34.26it/s]
# 100%|██████████| 28800/28800 [14:11<00:00, 33.80it/s]
# 100%|██████████| 200/200 [00:06<00:00, 32.20it/s]
# 100%|██████████| 28800/28800 [14:21<00:00, 33.42it/s]
# 100%|██████████| 200/200 [00:05<00:00, 34.54it/s]
# 100%|██████████| 28800/28800 [14:07<00:00, 34.00it/s]
# 100%|██████████| 200/200 [00:06<00:00, 31.09it/s]
#   5%|▍         | 1341/28800 [00:41<11:30, 39.79it/s]
